# %% [markdown]
# https://towardsdatascience.com/technical-analysis-of-stocks-using-ta-lib-305614165051

# %% [markdown]
# Another way to show market indicators

# %%
import yfinance as yf
import numpy 
import talib as ta
import pandas as pd
import matplotlib.pyplot as plt

# %%
power = yf.Ticker("POWERGRID.NS")
df = power.history(start="2020-01-01", end='2020-09-04')
df.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2020-01-01  171.911562  176.738249  171.640903  176.377380  7661462
# 2020-01-02  176.422476  177.459984  175.339855  176.016495  3191453
# 2020-01-03  175.249635  175.745840  172.543077  174.121902  4139027
# 2020-01-06  173.219702  174.978962  169.610959  174.212112  4137352
# 2020-01-07  174.257233  175.475190  172.452861  172.949066  7888340
#
#             Dividends  Stock Splits
# Date
# 2020-01-01        0.0             0
# 2020-01-02        0.0             0
# 2020-01-03        0.0             0
# 2020-01-06        0.0             0
# 2020-01-07        0.0             0

# %% [markdown]
# Simple Moving Average

# %%
df['MA'] = ta.SMA(df['Close'],20)
df[['Close','MA']].plot(figsize=(12,12))
plt.show()

# %% [markdown]
# Exponential Moving Average

# %%
df['EMA'] = ta.EMA(df['Close'], timeperiod = 20)
df[['Close','EMA']].plot(figsize=(12,10))
plt.show()

# %% [markdown]
# Average Directional Movement Index [Momentum Indicator]

# %%
df['avg'] = ta.ADX(df['High'],df['Low'], df['Close'], timeperiod=20)
df[['avg']].plot(figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Relative Strength Index [RSI]

# %%
df['Relative'] = ta.RSI(df['Close'],14)
df['Relative'].plot(figsize=(12,10))
plt.show()

# %% [markdown]
# https://towardsdatascience.com/technical-analysis-of-stocks-using-ta-lib-305614165051

# %% [markdown]
# Another way to show market indicators

# %%
import yfinance as yf
import numpy 
import talib as ta
import pandas as pd
import matplotlib.pyplot as plt

# %%
#power = yf.Ticker("POWERGRID.NS")
power = yf.Ticker("KO")
df = power.history(start="2021-01-01", end='2021-03-30')
df.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-01-04  53.419501  53.773859  51.214603  51.933163  25611100        0.0
# 2021-01-05  51.509906  51.795358  51.214604  51.362255  20323800        0.0
# 2021-01-06  51.155548  51.204764  49.403441  49.728271  38724500        0.0
# 2021-01-07  49.305008  49.472342  48.743941  49.177044  53225700        0.0
# 2021-01-08  49.245947  50.328711  49.058926  50.279495  29674000        0.0
#
#             Stock Splits
# Date
# 2021-01-04             0
# 2021-01-05             0
# 2021-01-06             0
# 2021-01-07             0
# 2021-01-08             0

# %% [markdown]
# Simple Moving Average

# %%
df['MA'] = ta.SMA(df['Close'],20)
df[['Close','MA']].plot(figsize=(12,12))
plt.show()

# %% [markdown]
# Exponential Moving Average

# %%
df['EMA'] = ta.EMA(df['Close'], timeperiod = 20)
df[['Close','EMA']].plot(figsize=(12,10))
plt.show()

# %% [markdown]
# Average Directional Movement Index [Momentum Indicator]

# %%
df['avg'] = ta.ADX(df['High'],df['Low'], df['Close'], timeperiod=20)
df[['avg']].plot(figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Relative Strength Index [RSI]

# %%
df['Relative'] = ta.RSI(df['Close'],14)
df['Relative'].plot(figsize=(12,10))
plt.show()
